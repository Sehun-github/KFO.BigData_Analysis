# %% [markdown]
# ## 수평선, 수직선그리기
# * 수평선 그리기
# * 수직선 그리기

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 그래프에 한글폰트 설정
plt.rcParams['font.family']='Malgun Gothic'

# 그래프에 마이너스 기호 깨지는 문제 해결
plt.rcParams['axes.unicode_minus'] = False
# 그리드 스타일
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['grid.alpha'] = 0.3

# %% [markdown]
# ## 수평선 그리기
# * `plt.axhline(y좌표, x축시작위치, x축끝위치)` x전체를 1로 본다
# 수평선의 길이가 1이라고 했을 때 x축시작위치, x축끝위치를 지정한다.
# 따로 지정하지 않으면 x축 전범위에 걸쳐 그려진다.
# * `plt.hlines(y, x축시작좌표, x축끝좌표)`

# %%
plt.plot([1,2,3,4], 'ko')
plt.axhline(2,0, color='b', alpha=0.5, ls=':')
plt.hlines(3,0,3, color='darkorange', ls='-.')

plt.show()

# %% [markdown]
# ### 수직선 그리기
# * `axvline(x좌표, y축시작위치, y축끝위치)`
# 수직선의 길이가 1이라고 했을 때 y축시작위치, y축끝위치를 지정한다.
# 따로 지정하지 않으면 y축 전범위에 걸쳐 그려진다.
# * `vlines(x, y축시작좌표, y축끝좌표)`

# %%
plt.plot([1,2,3,4], 'ko')
plt.axvline(1,0,0.5,ls='--',color='r')
plt.vlines(2,1,3)
plt.show()
